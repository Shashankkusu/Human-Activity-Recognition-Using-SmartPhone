# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn tensorflow
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 621.2 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/11.3 MB 621.2 kB/s eta 0:00:18
#    -- ------------------------------------- 0.8/11.3 MB 713.3 kB/s eta 0:00:15
# ...

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import os
import warnings
from tensorflow import keras
from tensorflow.keras import layers
warnings.filterwarnings('ignore')

# %%
train_data = pd.read_csv(r"C:\Users\gowri\OneDrive\Desktop\human activity recognition\train.csv")
test_data = pd.read_csv(r"C:\Users\gowri\OneDrive\Desktop\human activity recognition\test.csv")

# %%
train_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
test_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
train_data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train_data.dtypes
# Out:
# tBodyAcc-mean()-X       float64
# tBodyAcc-mean()-Y       float64
# tBodyAcc-mean()-Z       float64
# tBodyAcc-std()-X        float64
# tBodyAcc-std()-Y        float64
#                          ...
# angle(X,gravityMean)    float64
# angle(Y,gravityMean)    float64
# angle(Z,gravityMean)    float64
# subject                   int64
# Activity                 object
# Length: 563, dtype: object

# %%
train_data['Activity'].unique()
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
train_data.shape
# Out:
# (7352, 563)

# %%
test_data.shape
# Out:
# (2947, 563)

# %%
train_data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
train_data['Activity'].value_counts()
# Out:
# Activity
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: count, dtype: int64

# %%
train_data.isnull().sum()
# Out:
# tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 563, dtype: int64

# %%
potability_counts = train_data['Activity'].value_counts()

colors = ['#66c2a5', '#fc8d62', 'cyan', 'blue', 'red']

explode = [0.1] + [0] * (len(potability_counts) - 1)

plt.figure(figsize=(10, 6))
plt.pie(
    potability_counts,
    labels=potability_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors[:len(potability_counts)],  
    explode=explode,
    shadow=True
)
plt.title('Class Distribution', fontsize=20, fontweight='bold', color='#333333')
plt.axis('equal')
plt.show()

# %%
x_train, y_train = train_data.iloc[:, :-2], train_data.iloc[:, -1:]
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352, 1))

# %%
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_test.shape, y_test.shape
# Out:
# ((2947, 561), (2947, 1))

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %%
scaling_data = MinMaxScaler()
x_train = scaling_data.fit_transform(x_train)
x_test = scaling_data.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM, TimeDistributed
from sklearn.metrics import accuracy_score

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical

# %%
num_classes = len(np.unique(y_train))
y_train_onehot = to_categorical(y_train, num_classes=num_classes)
y_test_onehot = to_categorical(y_test, num_classes=num_classes)

x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %% [markdown]
# ## ConvLSTM Model:

# %%
model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(x_train.shape[1], 1)),
    Dropout(0.2),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 559, 64)             │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 559, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 559, 64)             │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 559, 64)             │               0 │
# ...

# %%
history = model.fit(x_train, y_train_onehot, validation_split=0.2, epochs=20, batch_size=64, verbose=1)
# Out:
# Epoch 1/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 56s 565ms/step - accuracy: 0.6121 - loss: 0.8672 - val_accuracy: 0.8926 - val_loss: 0.3516
# Epoch 2/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 53s 582ms/step - accuracy: 0.8900 - loss: 0.2881 - val_accuracy: 0.9361 - val_loss: 0.1530
# Epoch 3/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 50s 547ms/step - accuracy: 0.9407 - loss: 0.1576 - val_accuracy: 0.9443 - val_loss: 0.1376
# Epoch 4/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 50s 542ms/step - accuracy: 0.9471 - loss: 0.1322 - val_accuracy: 0.9497 - val_loss: 0.1445
# Epoch 5/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 51s 555ms/step - accuracy: 0.9582 - loss: 0.1047 - val_accuracy: 0.9470 - val_loss: 0.1309
# Epoch 6/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 51s 556ms/step - accuracy: 0.9634 - loss: 0.0889 - val_accuracy: 0.9511 - val_loss: 0.1318
# Epoch 7/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 49s 537ms/step - accuracy: 0.9733 - loss: 0.0728 - val_accuracy: 0.9490 - val_loss: 0.1183
# Epoch 8/20
# ...

# %%
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step
# Accuracy: 0.95

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       537
#            1       0.91      0.90      0.91       491
#            2       0.92      0.92      0.92       532
#            3       0.96      0.99      0.98       496
#            4       0.98      0.91      0.94       420
#            5       0.93      0.97      0.95       471
#
#     accuracy                           0.95      2947
#    macro avg       0.95      0.95      0.95      2947
# weighted avg       0.95      0.95      0.95      2947

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
fpr, tpr, roc_auc = {}, {}, {}
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_onehot[:, i], y_pred_prob[:, i])
    roc_auc[i] = roc_auc_score(y_test_onehot[:, i], y_pred_prob[:, i])

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
auc_macro = roc_auc_score(y_test_onehot, y_pred_prob, multi_class="ovr")

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Matthews Correlation Coefficient: {mcc:.2f}")
print(f"AUC-ROC (Macro): {auc_macro:.2f}")
# Out:
# Precision: 0.95
# Recall: 0.95
# F1 Score: 0.95
# Matthews Correlation Coefficient: 0.94
# AUC-ROC (Macro): 1.00

# %%
model.save("har_conv-lstm_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## CNN Model Implementation

# %%
def build_cnn(input_shape, num_classes):
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Dropout(0.5),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
x_train_cnn = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test_cnn = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

cnn_model = build_cnn(x_train_cnn.shape[1:], len(np.unique(y_train)))
cnn_history = cnn_model.fit(x_train_cnn, y_train, epochs=20, batch_size=64, validation_data=(x_test_cnn, y_test))
# Out:
# Epoch 1/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8143 - loss: 0.4758 - val_accuracy: 0.8951 - val_loss: 0.2628
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.9392 - loss: 0.1661 - val_accuracy: 0.9175 - val_loss: 0.2029
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9528 - loss: 0.1272 - val_accuracy: 0.9369 - val_loss: 0.1658
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.9616 - loss: 0.1011 - val_accuracy: 0.9138 - val_loss: 0.2270
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.9732 - loss: 0.0757 - val_accuracy: 0.9505 - val_loss: 0.1448
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.9748 - loss: 0.0699 - val_accuracy: 0.9427 - val_loss: 0.1633
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.9747 - loss: 0.0689 - val_accuracy: 0.9488 - val_loss: 0.1551
# Epoch 8/20
# ...

# %%
cnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)                    │ (None, 559, 64)             │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 279, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 279, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 17856)               │               0 │
# ...

# %%
train_loss, train_acc = cnn_model.evaluate(x_train_cnn, y_train, verbose=0)
test_loss, test_acc = cnn_model.evaluate(x_test_cnn, y_test, verbose=0)

print(f"CNN Train Accuracy: {train_acc:.4f}")
print(f"CNN Test Accuracy: {test_acc:.4f}")
# Out:
# CNN Train Accuracy: 0.9910
# CNN Test Accuracy: 0.9515

# %%
import numpy as np
from sklearn.metrics import accuracy_score

y_train_pred = np.argmax(cnn_model.predict(x_train_cnn), axis=1)
y_test_pred = np.argmax(cnn_model.predict(x_test_cnn), axis=1)

train_acc_sk = accuracy_score(y_train, y_train_pred)
test_acc_sk  = accuracy_score(y_test, y_test_pred)

print(f"CNN Train Accuracy (sklearn): {train_acc_sk:.4f}")
print(f"CNN Test Accuracy (sklearn): {test_acc_sk:.4f}")
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# CNN Train Accuracy (sklearn): 0.9910
# CNN Test Accuracy (sklearn): 0.9515

# %%
def plot_history(history, title):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Test Accuracy')
    plt.title(f'{title} Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title(f'{title} Loss')
    plt.legend()
    plt.show()
    
plot_history(cnn_history, "CNN")

train_acc_cnn = cnn_model.evaluate(x_train_cnn, y_train, verbose=0)[1]
test_acc_cnn = cnn_model.evaluate(x_test_cnn, y_test, verbose=0)[1]
print(f'CNN Train Accuracy: {train_acc_cnn:.4f}, Test Accuracy: {test_acc_cnn:.4f}')
# Out:
# CNN Train Accuracy: 0.9951, Test Accuracy: 0.9627

# %%
cnn_model.save('har_cnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM Model Implementation

# %%
def build_lstm(input_shape, num_classes):
    model = Sequential([
        LSTM(100, input_shape=input_shape, return_sequences=True),
        LSTM(100),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
x_train_lstm = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test_lstm = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

lstm_model = build_lstm(x_train_lstm.shape[1:], len(np.unique(y_train)))
lstm_history = lstm_model.fit(x_train_lstm, y_train, epochs=20, batch_size=64, validation_data=(x_test_lstm, y_test))
# Out:
# Epoch 1/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.3349 - loss: 1.2938 - val_accuracy: 0.4462 - val_loss: 1.1011
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.4343 - loss: 1.0585 - val_accuracy: 0.4540 - val_loss: 1.1174
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 356s 3s/step - accuracy: 0.4631 - loss: 1.0294 - val_accuracy: 0.4907 - val_loss: 0.9943
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.4895 - loss: 0.9898 - val_accuracy: 0.4761 - val_loss: 0.9777
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.4894 - loss: 0.9809 - val_accuracy: 0.5070 - val_loss: 0.9765
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.5026 - loss: 0.9719 - val_accuracy: 0.4642 - val_loss: 0.9902
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.5113 - loss: 0.9604 - val_accuracy: 0.5117 - val_loss: 0.9531
# Epoch 8/20
# ...

# %%
lstm_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 561, 100)            │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100)                 │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          12,928 │
# ...

# %%
plot_history(lstm_history, "LSTM")

train_acc_lstm = lstm_model.evaluate(x_train_lstm, y_train, verbose=0)[1]
test_acc_lstm = lstm_model.evaluate(x_test_lstm, y_test, verbose=0)[1]
print(f'LSTM Train Accuracy: {train_acc_lstm:.4f}, Test Accuracy: {test_acc_lstm:.4f}')
# Out:
# LSTM Train Accuracy: 0.8418, Test Accuracy: 0.8110

# %%
lstm_model.save('har_lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## CNN-LSTM Model Implementation

# %%
def build_cnn_lstm(input_shape, num_classes):
    model = Sequential([
        TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=input_shape),
        TimeDistributed(MaxPooling1D(pool_size=2)),
        TimeDistributed(Flatten()),
        LSTM(100),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
x_train_cnn_lstm = x_train.reshape(x_train.shape[0], 1, x_train.shape[1], 1)
x_test_cnn_lstm = x_test.reshape(x_test.shape[0], 1, x_test.shape[1], 1)

cnn_lstm_model = build_cnn_lstm(x_train_cnn_lstm.shape[1:], len(np.unique(y_train)))
cnn_lstm_history = cnn_lstm_model.fit(x_train_cnn_lstm, y_train, epochs=20, batch_size=64, validation_data=(x_test_cnn_lstm, y_test))
# Out:
# Epoch 1/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 25s 182ms/step - accuracy: 0.7229 - loss: 0.6530 - val_accuracy: 0.8873 - val_loss: 0.2756
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 20s 177ms/step - accuracy: 0.9298 - loss: 0.1974 - val_accuracy: 0.9108 - val_loss: 0.2088
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 18s 154ms/step - accuracy: 0.9582 - loss: 0.1143 - val_accuracy: 0.9335 - val_loss: 0.1689
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 19s 161ms/step - accuracy: 0.9698 - loss: 0.0847 - val_accuracy: 0.9501 - val_loss: 0.1378
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 19s 162ms/step - accuracy: 0.9735 - loss: 0.0731 - val_accuracy: 0.9501 - val_loss: 0.1498
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 19s 169ms/step - accuracy: 0.9758 - loss: 0.0625 - val_accuracy: 0.9454 - val_loss: 0.1644
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 19s 164ms/step - accuracy: 0.9792 - loss: 0.0544 - val_accuracy: 0.9318 - val_loss: 0.2139
# Epoch 8/20
# ...

# %%
cnn_lstm_model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_3 (TimeDistributed) │ (None, 1, 559, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_4 (TimeDistributed) │ (None, 1, 279, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 1, 17856)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 100)                 │       7,182,800 │
# ...

# %%
plot_history(cnn_lstm_history, "CNN-LSTM")

train_acc_cnn_lstm = cnn_lstm_model.evaluate(x_train_cnn_lstm, y_train, verbose=0)[1]
test_acc_cnn_lstm = cnn_lstm_model.evaluate(x_test_cnn_lstm, y_test, verbose=0)[1]
print(f'CNN-LSTM Train Accuracy: {train_acc_cnn_lstm:.4f}, Test Accuracy: {test_acc_cnn_lstm:.4f}')
# Out:
# CNN-LSTM Train Accuracy: 0.9952, Test Accuracy: 0.9559

# %%
cnn_lstm_model.save('har_cnn_lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(f'CNN Train Accuracy: {train_acc_cnn:.4f}, Test Accuracy: {test_acc_cnn:.4f}')
print(f'LSTM Train Accuracy: {train_acc_lstm:.4f}, Test Accuracy: {test_acc_lstm:.4f}')
print(f'CNN-LSTM Train Accuracy: {train_acc_cnn_lstm:.4f}, Test Accuracy: {test_acc_cnn_lstm:.4f}')
# Out:
# CNN Train Accuracy: 0.9951, Test Accuracy: 0.9627
# LSTM Train Accuracy: 0.8418, Test Accuracy: 0.8110
# CNN-LSTM Train Accuracy: 0.9952, Test Accuracy: 0.9559

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv(r"C:\Users\gowri\OneDrive\Desktop\human activity recognition\train.csv")
test_data = pd.read_csv(r"C:\Users\gowri\OneDrive\Desktop\human activity recognition\test.csv")

# %%
x_train = train_data.iloc[:, :-1] # all columns except last
y_train = train_data.iloc[:, -1] # last column as target
x_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
xgb_model = XGBClassifier(n_estimators=300, learning_rate=0.05, max_depth=6, objective='multi', eval_metric='mlogloss')
xgb_model.fit(x_train, y_train)
y_pred_xgb = xgb_model.predict(x_test)
xgb_train_acc = accuracy_score(y_train, xgb_model.predict(x_train))
xgb_test_acc = accuracy_score(y_test, y_pred_xgb)

# %%
cat_model = CatBoostClassifier(iterations=300, learning_rate=0.05, depth=6, verbose=0)
cat_model.fit(x_train, y_train)
y_pred_cat = cat_model.predict(x_test)
cat_train_acc = accuracy_score(y_train, cat_model.predict(x_train))
cat_test_acc = accuracy_score(y_test, y_pred_cat)

# %%
print("=== XGBoost Metrics ===")
print(f"Train Accuracy: {xgb_train_acc:.4f}")
print(f"Test Accuracy : {xgb_test_acc:.4f}")
print("\nClassification Report (Test):")
print(classification_report(y_test, y_pred_xgb))
print("Confusion Matrix (Test):")
print(confusion_matrix(y_test, y_pred_xgb))


print("\n=== CatBoost Metrics ===")
print(f"Train Accuracy: {cat_train_acc:.4f}")
print(f"Test Accuracy : {cat_test_acc:.4f}")
print("\nClassification Report (Test):")
print(classification_report(y_test, y_pred_cat))
print("Confusion Matrix (Test):")
print(confusion_matrix(y_test, y_pred_cat))
# Out:
# === XGBoost Metrics ===
# Train Accuracy: 1.0000
# Test Accuracy : 0.9274
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       537
#            1       0.91      0.83      0.87       491
#            2       0.86      0.93      0.89       532
#            3       0.92      0.98      0.95       496
#            4       0.97      0.91      0.94       420
#            5       0.92      0.92      0.92       471
#
#     accuracy                           0.93      2947
#    macro avg       0.93      0.93      0.93      2947
# weighted avg       0.93      0.93      0.93      2947
#
# Confusion Matrix (Test):
# [[537   0   0   0   0   0]
#  [  0 406  82   0   0   3]
#  [  0  39 493   0   0   0]
#  [  0   0   0 485   6   5]
#  [  0   0   0   9 381  30]
#  [  0   0   0  35   5 431]]
#
# === CatBoost Metrics ===
# Train Accuracy: 0.9974
# Test Accuracy : 0.9104
#
# Classification Report (Test):
# ...

# %%
models = ['XGBoost', 'CatBoost']
train_acc = [xgb_train_acc, cat_train_acc]
test_acc = [xgb_test_acc, cat_test_acc]

x = range(len(models))
plt.figure(figsize=(8,5))
plt.bar([i-0.15 for i in x], train_acc, width=0.3, label='Train Accuracy')
plt.bar([i+0.15 for i in x], test_acc, width=0.3, label='Test Accuracy')
plt.xticks(x, models)
plt.ylabel('Accuracy')
plt.title('HAR Model Comparison')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# %%
input_shape = x_train.shape[1:]

cnn_model = Sequential([
Conv1D(64, kernel_size=3, activation='relu', input_shape=(input_shape[0], 1)),
MaxPooling1D(pool_size=2),
Dropout(0.3),
Flatten(),
Dense(128, activation='relu')
])

# %%
x_train_cnn = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test_cnn = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy')
train_features = cnn_model.predict(x_train_cnn)
test_features = cnn_model.predict(x_test_cnn)
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
xgb_cnn_model = XGBClassifier(n_estimators=300, learning_rate=0.05, max_depth=6, objective='multi', eval_metric='mlogloss')
xgb_cnn_model.fit(train_features, y_train)
y_pred_cnn_xgb = xgb_cnn_model.predict(test_features)

cnn_xgb_train_acc = accuracy_score(y_train, xgb_cnn_model.predict(train_features))
cnn_xgb_test_acc = accuracy_score(y_test, y_pred_cnn_xgb)

# %%
print("=== CNN + XGBoost Metrics ===")
print(f"Train Accuracy: {cnn_xgb_train_acc:.4f}, Test Accuracy: {cnn_xgb_test_acc:.4f}")
print(f"Train F1-score: {f1_score(y_train, xgb_cnn_model.predict(train_features), average='weighted'):.4f}, "
f"Test F1-score: {f1_score(y_test, y_pred_cnn_xgb, average='weighted'):.4f}")
print("\nClassification Report (Test):")
print(classification_report(y_test, y_pred_cnn_xgb))
# Out:
# === CNN + XGBoost Metrics ===
# Train Accuracy: 1.0000, Test Accuracy: 0.8890
# Train F1-score: 1.0000, Test F1-score: 0.8891
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       537
#            1       0.86      0.78      0.82       491
#            2       0.80      0.89      0.84       532
#            3       0.89      0.93      0.91       496
#            4       0.91      0.84      0.87       420
#            5       0.90      0.92      0.91       471
#
#     accuracy                           0.89      2947
#    macro avg       0.89      0.89      0.89      2947
# weighted avg       0.89      0.89      0.89      2947

# %%
models = ['XGBoost', 'CatBoost', 'CNN+XGBoost']
train_acc = [xgb_train_acc, cat_train_acc, cnn_xgb_train_acc]
test_acc = [xgb_test_acc, cat_test_acc, cnn_xgb_test_acc]

x = range(len(models))
plt.figure(figsize=(8,5))
plt.bar([i-0.15 for i in x], train_acc, width=0.3, label='Train Accuracy')
plt.bar([i+0.15 for i in x], test_acc, width=0.3, label='Test Accuracy')
plt.xticks(x, models)
plt.ylabel('Accuracy')
plt.title('HAR Model Comparison')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score

# %%
rf_model = RandomForestClassifier(n_estimators=300, max_depth=None, random_state=42)
rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test)

rf_train_acc = accuracy_score(y_train, rf_model.predict(x_train))
rf_test_acc = accuracy_score(y_test, y_pred_rf)

# %%
print("=== Random Forest Metrics ===")
print(f"Train Accuracy: {rf_train_acc:.4f}, Test Accuracy: {rf_test_acc:.4f}")
print(f"Train F1-score: {f1_score(y_train, rf_model.predict(x_train), average='weighted'):.4f}, "
f"Test F1-score: {f1_score(y_test, y_pred_rf, average='weighted'):.4f}")
print("\nClassification Report (Test):")
print(classification_report(y_test, y_pred_rf))
# Out:
# === Random Forest Metrics ===
# Train Accuracy: 1.0000, Test Accuracy: 0.9321
# Train F1-score: 1.0000, Test F1-score: 0.9319
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       537
#            1       0.91      0.90      0.91       491
#            2       0.91      0.92      0.92       532
#            3       0.91      0.97      0.94       496
#            4       0.96      0.86      0.90       420
#            5       0.90      0.92      0.91       471
#
#     accuracy                           0.93      2947
#    macro avg       0.93      0.93      0.93      2947
# weighted avg       0.93      0.93      0.93      2947

# %%
models = ['XGBoost', 'CatBoost', 'CNN+XGBoost', 'Random Forest']
train_acc = [xgb_train_acc, cat_train_acc, cnn_xgb_train_acc, rf_train_acc]
test_acc = [xgb_test_acc, cat_test_acc, cnn_xgb_test_acc, rf_test_acc]

x = range(len(models))
plt.figure(figsize=(9,5))
plt.bar([i-0.15 for i in x], train_acc, width=0.3, label='Train Accuracy')
plt.bar([i+0.15 for i in x], test_acc, width=0.3, label='Test Accuracy')
plt.xticks(x, models)
plt.ylabel('Accuracy')
plt.title('HAR Model Comparison')
plt.legend()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train, y_train)
y_pred_knn = knn_model.predict(x_test)

knn_train_acc = accuracy_score(y_train, knn_model.predict(x_train))
knn_test_acc = accuracy_score(y_test, y_pred_knn)

# %%
svm_model = SVC(kernel='rbf', probability=True)
svm_model.fit(x_train, y_train)
y_pred_svm = svm_model.predict(x_test)

svm_train_acc = accuracy_score(y_train, svm_model.predict(x_train))
svm_test_acc = accuracy_score(y_test, y_pred_svm)

# %%
print("=== KNN Metrics ===")
print(f"Train Accuracy: {knn_train_acc:.4f}, Test Accuracy: {knn_test_acc:.4f}")
print("\n=== SVM Metrics ===")
print(f"Train Accuracy: {svm_train_acc:.4f}, Test Accuracy: {svm_test_acc:.4f}")
# Out:
# === KNN Metrics ===
# Train Accuracy: 0.9856, Test Accuracy: 0.9030
#
# === SVM Metrics ===
# Train Accuracy: 0.9805, Test Accuracy: 0.9511

# %%
models = ['XGBoost', 'CatBoost', 'CNN+XGBoost', 'Random Forest', 'KNN', 'SVM']
train_acc = [xgb_train_acc, cat_train_acc, cnn_xgb_train_acc, rf_train_acc, knn_train_acc, svm_train_acc]
test_acc = [xgb_test_acc, cat_test_acc, cnn_xgb_test_acc, rf_test_acc, knn_test_acc, svm_test_acc]

x = range(len(models))
plt.figure(figsize=(10,5))
plt.bar([i-0.15 for i in x], train_acc, width=0.3, label='Train Accuracy')
plt.bar([i+0.15 for i in x], test_acc, width=0.3, label='Test Accuracy')
plt.xticks(x, models)
plt.ylabel('Accuracy')
plt.title('HAR Model Comparison')
plt.show()

# %%
import lightgbm as lgb

# %%
lgb_model = lgb.LGBMClassifier(n_estimators=300, learning_rate=0.05, max_depth=6)
lgb_model.fit(x_train, y_train)
y_pred_lgb = lgb_model.predict(x_test)

lgb_train_acc = accuracy_score(y_train, lgb_model.predict(x_train))
lgb_test_acc = accuracy_score(y_test, y_pred_lgb)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049620 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140184
# [LightGBM] [Info] Number of data points in the train set: 7352, number of used features: 562
# [LightGBM] [Info] Start training from score -1.653513
# [LightGBM] [Info] Start training from score -1.743436
# [LightGBM] [Info] Start training from score -1.677246
# [LightGBM] [Info] Start training from score -1.791216
# [LightGBM] [Info] Start training from score -2.009071
# [LightGBM] [Info] Start training from score -1.924514
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
print("=== LightGBM Metrics ===")
print(f"Train Accuracy: {lgb_train_acc:.4f}, Test Accuracy: {lgb_test_acc:.4f}")
# Out:
# === LightGBM Metrics ===
# Train Accuracy: 1.0000, Test Accuracy: 0.9359

# %%
models = ['XGBoost', 'CatBoost', 'CNN+XGBoost', 'Random Forest', 'KNN', 'SVM', 'LightGBM']
train_acc = [xgb_train_acc, cat_train_acc, cnn_xgb_train_acc, rf_train_acc, knn_train_acc, svm_train_acc, lgb_train_acc]
test_acc = [xgb_test_acc, cat_test_acc, cnn_xgb_test_acc, rf_test_acc, knn_test_acc, svm_test_acc, lgb_test_acc]

x = range(len(models))
plt.figure(figsize=(12,5))
plt.bar([i-0.15 for i in x], train_acc, width=0.3, label='Train Accuracy')
plt.bar([i+0.15 for i in x], test_acc, width=0.3, label='Test Accuracy')
plt.xticks(x, models, rotation=15)
plt.ylabel('Accuracy')
plt.title('HAR Model Comparison')
plt.show()

# %%
# --- Add CNN metrics ---

cnn_train_acc = 0.9910
cnn_test_acc  = 0.9515

models = ['XGBoost', 'CatBoost', 'CNN+XGBoost', 'Random Forest', 'KNN', 'SVM', 'LightGBM', 'CNN']
train_acc = [xgb_train_acc, cat_train_acc, cnn_xgb_train_acc, rf_train_acc, knn_train_acc, svm_train_acc, lgb_train_acc, cnn_train_acc]
test_acc  = [xgb_test_acc, cat_test_acc, cnn_xgb_test_acc, rf_test_acc, knn_test_acc, svm_test_acc, lgb_test_acc, cnn_test_acc]

x = range(len(models))
plt.figure(figsize=(14,5))
plt.bar([i-0.15 for i in x], train_acc, width=0.3, label='Train Accuracy')
plt.bar([i+0.15 for i in x], test_acc, width=0.3, label='Test Accuracy')
plt.xticks(x, models, rotation=15)
plt.ylabel('Accuracy')
plt.title('HAR Model Comparison')
plt.show()

# %%
# --- Print all train and test accuracies ---

print(f"{'Model':<15} {'Train Accuracy':<15} {'Test Accuracy':<15}")
print("-"*45)
for i in range(len(models)):
    print(f"{models[i]:<15} {train_acc[i]:<15.4f} {test_acc[i]:<15.4f}")
# Out:
# Model           Train Accuracy  Test Accuracy
# ---------------------------------------------
# XGBoost         1.0000          0.9274
# CatBoost        0.9974          0.9104
# CNN+XGBoost     1.0000          0.8890
# Random Forest   1.0000          0.9321
# KNN             0.9856          0.9030
# SVM             0.9805          0.9511
# LightGBM        1.0000          0.9359
# CNN             0.9910          0.9515
